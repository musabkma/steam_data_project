# %%
import matplotlib.pyplot as plt
df["Price"].hist()
plt.show()
plt.savefig("../images/price_distribution.png")

# %%
df["Playtime Hours"] = df["Average playtime forever"] / 60

top_games = df.sort_values(
    by=["Playtime Hours", "Price"],
    ascending=[False, False]
)

top_10 = top_games[[
    "AppID",
    "Price",
    "Playtime Hours"
]].head(10)

print(top_10.to_string(index=False))
# Out:
#                                      AppID  Price  Playtime Hours
#                                     Avem33      0    57159.066667
#                     iTownGamePlay UNIVERSE      0    28571.250000
# Letters From a Rainy Day -Oceans and Lace-     30     5994.416667
#                                   爱人 Lover     65     5383.050000
#                                       KAMI      0     3278.933333
#                                       秘密舞会     60     3157.266667
#            VEGAS Pro 18 Edit Steam Edition     70     3084.300000
#                     Wizard And Minion Idle      0     2845.833333
#  Love Stories: When Pastel Meets Grotesque     60     2646.066667
#                 Franchise Hockey Manager 9      0     2529.450000

# %%
df[df["AppID"] == "Counter-Strike 2"]
# Out:
#                 AppID          Name           Release date  Estimated owners  \
# 730  Counter-Strike 2  Aug 21, 2012  100000000 - 200000000           1013936
#
#      Peak CCU  Required age  Price  DiscountDLC count  \
# 730         0           0.0      0                  1
#
#                                         About the game  \
# 730  For over two decades, Counter-Strike has offer...
#
#                                    Supported languages  ...  \
# 730  ['Czech', 'Danish', 'Dutch', 'English', 'Finni...  ...
#
#     Median playtime forever Median playtime two weeks Developers Publishers  \
# 730                    6237                       307      Valve      Valve
#
#                                             Categories               Genres  \
# 730  Multi-player,Cross-Platform Multiplayer,Steam ...  Action,Free To Play
#
#                                                   Tags  \
# 730  FPS,Shooter,Multiplayer,Competitive,Action,Tea...
#
#                                            Screenshots  Movies  Playtime Hours
# 730  https://shared.akamai.steamstatic.com/store_it...     NaN           565.1
#
# [1 rows x 40 columns]

# %%
df["Genres"].value_counts().head(10)
# Out:
# Genres
# Casual,Indie              6700
# Action,Indie              5679
# Action,Adventure,Indie    5159
# Adventure,Indie           4311
# Adventure,Casual,Indie    3610
# Action,Casual,Indie       3422
# Casual                    3351
# Indie                     3075
# Action                    2954
# Casual,Indie,Strategy     2250
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Estimated owners       Peak CCU   Required age          Price  \
# count      1.226110e+05  122611.000000  122611.000000  122611.000000
# mean       5.459332e+01       0.167611       4.765091      18.353663
# std        3.729452e+03       1.653591      12.531030      28.858970
# min        0.000000e+00       0.000000       0.000000       0.000000
# 25%        0.000000e+00       0.000000       0.550000       0.000000
# 50%        0.000000e+00       0.000000       2.240000       0.000000
# 75%        0.000000e+00       0.000000       5.240000      40.000000
# max        1.013936e+06      21.000000     999.980000     100.000000
#
#        DiscountDLC count  Metacritic score     User score      Positive  \
# count      122611.000000     122611.000000  122611.000000  1.226110e+05
# mean            0.545856          2.564941       0.024549  1.044986e+03
# std            14.516026         13.660559       1.394901  2.809173e+04
# min             0.000000          0.000000       0.000000  0.000000e+00
# 25%             0.000000          0.000000       0.000000  0.000000e+00
# 50%             0.000000          0.000000       0.000000  5.000000e+00
# 75%             0.000000          0.000000       0.000000  3.700000e+01
# max          3703.000000         97.000000     100.000000  7.642084e+06
#
#            Negative  Score rank   Achievements  Recommendations  \
# count  1.226110e+05   40.000000  122611.000000     1.226110e+05
# mean   1.691974e+02   99.175000      18.087015     9.618250e+02
# std    5.374645e+03    0.675107     141.493879     2.187880e+04
# min    0.000000e+00   98.000000       0.000000     0.000000e+00
# 25%    0.000000e+00   99.000000       0.000000     0.000000e+00
# 50%    1.000000e+00   99.000000       2.000000     0.000000e+00
# 75%    1.000000e+01  100.000000      19.000000     0.000000e+00
# max    1.173003e+06  100.000000    9821.000000     4.830455e+06
#
#        Average playtime forever  Average playtime two weeks  \
# count              1.226110e+05               122611.000000
# mean               2.080232e+02                   13.789268
# std                1.121768e+04                  270.378053
# min                0.000000e+00                    0.000000
# 25%                0.000000e+00                    0.000000
# 50%                0.000000e+00                    0.000000
# 75%                0.000000e+00                    0.000000
# max                3.429544e+06                20088.000000
#
#        Median playtime forever  Median playtime two weeks  Movies
# count             1.226110e+05              122611.000000     0.0
# mean              1.735705e+02                  14.722170     NaN
# std               1.120254e+04                 294.509615     NaN
# min               0.000000e+00                   0.000000     NaN
# 25%               0.000000e+00                   0.000000     NaN
# 50%               0.000000e+00                   0.000000     NaN
# 75%               0.000000e+00                   0.000000     NaN
# max               3.429544e+06               20088.000000     NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 122611 entries, 2539430 to 4141790
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       122610 non-null  str
#  1   Name                        122611 non-null  str
#  2   Release date                122611 non-null  str
#  3   Estimated owners            122611 non-null  int64
#  4   Peak CCU                    122611 non-null  int64
#  5   Required age                122611 non-null  float64
#  6   Price                       122611 non-null  int64
#  7   DiscountDLC count           122611 non-null  int64
#  8   About the game              114162 non-null  str
#  9   Supported languages         122611 non-null  str
#  10  Full audio languages        122611 non-null  str
#  11  Reviews                     12070 non-null   str
#  12  Header image                122530 non-null  str
#  13  Website                     49676 non-null   str
#  14  Support url                 54142 non-null   str
#  15  Support email               100348 non-null  str
#  16  Windows                     122611 non-null  bool
#  17  Mac                         122611 non-null  bool
#  18  Linux                       122611 non-null  bool
#  19  Metacritic score            122611 non-null  int64
#  20  Metacritic url              4256 non-null    str
#  21  User score                  122611 non-null  int64
#  22  Positive                    122611 non-null  int64
#  23  Negative                    122611 non-null  int64
#  24  Score rank                  40 non-null      float64
#  25  Achievements                122611 non-null  int64
#  26  Recommendations             122611 non-null  int64
#  27  Notes                       22458 non-null   str
#  28  Average playtime forever    122611 non-null  int64
#  29  Average playtime two weeks  122611 non-null  int64
#  30  Median playtime forever     122611 non-null  int64
#  31  Median playtime two weeks   122611 non-null  int64
#  32  Developers                  114174 non-null  str
#  33  Publishers                  113702 non-null  str
#  34  Categories                  113658 non-null  str
#  35  Genres                      114198 non-null  str
#  36  Tags                        83346 non-null   str
#  37  Screenshots                 116593 non-null  str
#  38  Movies                      0 non-null       float64
# dtypes: bool(3), float64(3), int64(14), str(19)
# memory usage: 35.0 MB

# %%
df.columns
# Out:
# Index(['AppID', 'Name', 'Release date', 'Estimated owners', 'Peak CCU',
#        'Required age', 'Price', 'DiscountDLC count', 'About the game',
#        'Supported languages', 'Full audio languages', 'Reviews',
#        'Header image', 'Website', 'Support url', 'Support email', 'Windows',
#        'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
#        'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
#        'Notes', 'Average playtime forever', 'Average playtime two weeks',
#        'Median playtime forever', 'Median playtime two weeks', 'Developers',
#        'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies'],
#       dtype='str')

# %%
import pandas as pd
df = pd.read_csv("../data/games.csv")
df.head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# 2539430                                                NaN
# 496350   Springtime, April: when the cherry trees come ...
# 1034400  Immerse yourself in the most beloved, mystical...
# 3292190  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# 3631080  Its not just a Maze; its a Quest! Enter the ca...
#
#                                 Supported languages  ...  \
# 2539430                                          []  ...
# 496350                                  ['English']  ...
# 1034400  ['English', 'French', 'German', 'Russian']  ...
# 3292190                                  ['Korean']  ...
# 3631080                                 ['English']  ...
#
#         Average playtime two weeks Median playtime forever  \
# 2539430                          0                       0
# 496350                           0                       8
# 1034400                          0                       0
# 3292190                          0                       0
# 3631080                          0                       0
#
#         Median playtime two weeks            Developers            Publishers  \
# 2539430                         0                   NaN                   NaN
# 496350                          0                minori            MangaGamer
# 1034400                         0           Somer Games                8floor
# 3292190                         0                 유진게임즈                 유진게임즈
# 3631080                         0  Reality Expanded LLC  Reality Expanded LLC
#
#                                                 Categories  \
# 2539430                                                NaN
# 496350   Single-player,Steam Trading Cards,Steam Cloud,...
# 1034400                       Single-player,Family Sharing
# 3292190    Single-player,Steam Achievements,Family Sharing
# 3631080  Single-player,VR Only,Steam Leaderboards,Famil...
#
#                           Genres  \
# 2539430                      NaN
# 496350                 Adventure
# 1034400                   Casual
# 3292190  Casual,Indie,Simulation
# 3631080      Action,Early Access
#
#                                                       Tags  \
# 2539430                                                NaN
# 496350                   Adventure,Visual Novel,Anime,Cute
# 1034400  Casual,Card Game,Solitaire,Puzzle,Hidden Objec...
# 3292190                                                NaN
# 3631080                                                NaN
#
#                                                Screenshots  Movies
# 2539430  https://shared.akamai.steamstatic.com/store_it...     NaN
# 496350   https://shared.akamai.steamstatic.com/store_it...     NaN
# 1034400  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3292190  https://shared.akamai.steamstatic.com/store_it...     NaN
# 3631080  https://shared.akamai.steamstatic.com/store_it...     NaN
#
# [5 rows x 39 columns]
